# %% [markdown]
# <a href="https://colab.research.google.com/github/sairaawahid/Employee-Attrition-Predictor-for-HR-Analytics/blob/main/Employee_Attrition_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1: Data Exploration Notebook
# File: notebooks/01_data_exploration.ipynb

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
url = "https://raw.githubusercontent.com/sairaawahid/Employee-Attrition-Predictor-for-HR-Analytics/refs/heads/main/data/WA_Fn-UseC_-HR-Employee-Attrition.csv?token=GHSAT0AAAAAADFEKMZXWRLB6NQDWT2SN4I22CBS6GQ"
df = pd.read_csv(url)

# Quick Glance
print("✅ Dataset loaded successfully!\n")
print("🔎 First 5 rows:")
display(df.head())

print("\n🧾 Dataset Info:")
df.info()

print("\n📊 Statistical Summary:")
display(df.describe(include='all'))

# Check for nulls and duplicates
print(f"\n🧼 Missing values:\n{df.isnull().sum()}")
print(f"\n🧼 Duplicates: {df.duplicated().sum()}")

# Basic Visualization - Attrition Count
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Attrition')
plt.title("Employee Attrition Distribution")
plt.show()

# Satisfaction vs Attrition
plt.figure(figsize=(8, 5))
sns.boxplot(x='Attrition', y='JobSatisfaction', data=df)
plt.title("Job Satisfaction by Attrition")
plt.show()

# Age vs Attrition
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Age', hue='Attrition', kde=True, multiple='stack')
plt.title("Age Distribution by Attrition")
plt.show()
# Out:
# ✅ Dataset loaded successfully!
#
# 🔎 First 5 rows:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...
